# %%
# !git clone https://github.com/kishkath/ERA3.git
# Out:
# Cloning into 'ERA3'...
# remote: Enumerating objects: 857, done.
# remote: Counting objects: 100% (151/151), done.
# remote: Compressing objects: 100% (138/138), done.
# remote: Total 857 (delta 90), reused 18 (delta 6), pack-reused 706 (from 1)
# Receiving objects: 100% (857/857), 9.60 MiB | 7.79 MiB/s, done.
# Resolving deltas: 100% (412/412), done.

# %%
import os
os.chdir("/content/ERA3/Session16/")

print(">>> current working directory: ", os.getcwd())
# Out:
# >>> current working directory:  /content/ERA3/Session16

# %%
from types import SimpleNamespace
from main import main

args = SimpleNamespace(
    data_root="./data/oxford-iiit-pet" ,         # Dataset will be downloaded here.
    epochs=10,                  # Use a small number of epochs for testing.
    batch_size=32,
    lr=1e-4,
    model_type="unet",
    step_size=8,
    gamma=0.1,
    bce_weight=0.5,
    plot_samples=12,
    loss_type="dice",
    checkpoint_path="/content/checkpoint.pth",
    infer_image="/content/dog.jpg"              # Provide a valid path to test inference, if desired.
)

main(args)
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.5' (you have '2.0.4'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Dataset not found. Downloading Oxford-IIIT Pet dataset via torchvision...
# Downloading https://thor.robots.ox.ac.uk/pets/images.tar.gz to data/oxford-iiit-pet/images.tar.gz
# 100%|██████████| 792M/792M [00:30<00:00, 25.9MB/s]
# Extracting data/oxford-iiit-pet/images.tar.gz to data/oxford-iiit-pet
# Downloading https://thor.robots.ox.ac.uk/pets/annotations.tar.gz to data/oxford-iiit-pet/annotations.tar.gz
# 100%|██████████| 19.2M/19.2M [00:01<00:00, 10.8MB/s]
# Extracting data/oxford-iiit-pet/annotations.tar.gz to data/oxford-iiit-pet
# [INFO] Using device: cuda
# [INFO] Loading dataset using CustomDataset...
# Before Removing:  7390 7390
# After Removing:  7384 7384
# [INFO] Dataset ready: 5907 training samples, 1477 validation samples.
# [INFO] Maxpool as Encoder & Transpose conv as Decoder
# Encoder initialized successfully.
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Decoder initialized successfully.
# UNet model with [MaxPool and Transpose Convolution] was initialized successfully.
# [INFO] unet model initialized.
# [INFO] Using loss function: dice
# [INFO] Optimizer and scheduler set.
#
# [INFO] Epoch 1/10
# [INFO] Epoch 1: Avg Train Loss: 0.3062 | Train Accuracy: 79.25%
# [INFO] Epoch 1: Avg Val Loss: 0.2554 | Val Accuracy: 84.48%
# [INFO] Saved best model with loss 0.2554 to /content/checkpoint.pth
# [INFO] Epoch completed in 5m 44s
#
# [INFO] Epoch 2/10
# [INFO] Epoch 2: Avg Train Loss: 0.1985 | Train Accuracy: 86.78%
# [INFO] Epoch 2: Avg Val Loss: 0.1726 | Val Accuracy: 87.73%
# [INFO] Saved best model with loss 0.1726 to /content/checkpoint.pth
# [INFO] Epoch completed in 5m 47s
#
# [INFO] Epoch 3/10
# [INFO] Epoch 3: Avg Train Loss: 0.1580 | Train Accuracy: 89.06%
# [INFO] Epoch 3: Avg Val Loss: 0.1462 | Val Accuracy: 89.89%
# [INFO] Saved best model with loss 0.1462 to /content/checkpoint.pth
# [INFO] Epoch completed in 5m 46s
#
# [INFO] Epoch 4/10
# [INFO] Epoch 4: Avg Train Loss: 0.1344 | Train Accuracy: 90.31%
# [INFO] Epoch 4: Avg Val Loss: 0.1364 | Val Accuracy: 90.25%
# [INFO] Saved best model with loss 0.1364 to /content/checkpoint.pth
# [INFO] Epoch completed in 5m 47s
#
# [INFO] Epoch 5/10
# [INFO] Epoch 5: Avg Train Loss: 0.1221 | Train Accuracy: 90.89%
# [INFO] Epoch 5: Avg Val Loss: 0.1257 | Val Accuracy: 89.87%
# [INFO] Saved best model with loss 0.1257 to /content/checkpoint.pth
# [INFO] Epoch completed in 5m 46s
#
# [INFO] Epoch 6/10
# [INFO] Epoch 6: Avg Train Loss: 0.1108 | Train Accuracy: 91.56%
# [INFO] Epoch 6: Avg Val Loss: 0.1157 | Val Accuracy: 90.92%
# [INFO] Saved best model with loss 0.1157 to /content/checkpoint.pth
# [INFO] Epoch completed in 5m 46s
#
# [INFO] Epoch 7/10
# [INFO] Epoch 7: Avg Train Loss: 0.1042 | Train Accuracy: 91.90%
# [INFO] Epoch 7: Avg Val Loss: 0.1610 | Val Accuracy: 88.29%
# [INFO] Epoch completed in 5m 46s
#
# [INFO] Epoch 8/10
# [INFO] Epoch 8: Avg Train Loss: 0.0946 | Train Accuracy: 92.58%
# [INFO] Epoch 8: Avg Val Loss: 0.1060 | Val Accuracy: 91.87%
# [INFO] Saved best model with loss 0.1060 to /content/checkpoint.pth
# [INFO] Epoch completed in 5m 46s
#
# [INFO] Epoch 9/10
# [INFO] Epoch 9: Avg Train Loss: 0.0805 | Train Accuracy: 93.72%
# [INFO] Epoch 9: Avg Val Loss: 0.0872 | Val Accuracy: 93.11%
# [INFO] Saved best model with loss 0.0872 to /content/checkpoint.pth
# [INFO] Epoch completed in 5m 46s
#
# [INFO] Epoch 10/10
# [INFO] Epoch 10: Avg Train Loss: 0.0761 | Train Accuracy: 94.11%
# [INFO] Epoch 10: Avg Val Loss: 0.0871 | Val Accuracy: 93.19%
# [INFO] Saved best model with loss 0.0871 to /content/checkpoint.pth
# [INFO] Epoch completed in 5m 47s
# [INFO] Training complete.
# [ERROR] Plotting samples failed: 'types.SimpleNamespace' object has no attribute 'plot_mode'
# [INFO] Running inference on: /content/dog.jpg
# /content/ERA3/Session16/main.py:144: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(args.checkpoint_path, map_location=device))
